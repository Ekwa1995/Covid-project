# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('C:/Users/user/Documents/GitHub/PortfolioProjects-main/CovidVaccinations.xlsx')
df.head(10)
# Out:
#   iso_code continent     location       date  total_tests  new_tests  \
# 0      AFG      Asia  Afghanistan 2020-01-03          NaN        NaN
# 1      AFG      Asia  Afghanistan 2020-01-04          NaN        NaN
# 2      AFG      Asia  Afghanistan 2020-01-05          NaN        NaN
# 3      AFG      Asia  Afghanistan 2020-01-06          NaN        NaN
# 4      AFG      Asia  Afghanistan 2020-01-07          NaN        NaN
# 5      AFG      Asia  Afghanistan 2020-01-08          NaN        NaN
# 6      AFG      Asia  Afghanistan 2020-01-09          NaN        NaN
# 7      AFG      Asia  Afghanistan 2020-01-10          NaN        NaN
# 8      AFG      Asia  Afghanistan 2020-01-11          NaN        NaN
# 9      AFG      Asia  Afghanistan 2020-01-12          NaN        NaN
#
#    total_tests_per_thousand  new_tests_per_thousand  new_tests_smoothed  \
# 0                       NaN                     NaN                 NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 346645 entries, 0 to 346644
# Data columns (total 45 columns):
# iso_code                                      346645 non-null object
# continent                                     330140 non-null object
# location                                      346645 non-null object
# date                                          346645 non-null datetime64[ns]
# total_tests                                   79387 non-null float64
# new_tests                                     75403 non-null float64
# total_tests_per_thousand                      79387 non-null float64
# new_tests_per_thousand                        75403 non-null float64
# new_tests_smoothed                            103965 non-null float64
# new_tests_smoothed_per_thousand               103965 non-null float64
# positive_rate                                 95927 non-null float64
# tests_per_case                                94348 non-null float64
# ...
